# %%
from datetime import datetime
#import MetaTrader5 as mt5
import pandas as pd
import pytz
import numpy as np
from ta.volatility import BollingerBands
from ta.momentum import StochasticOscillator
from ta.trend import MACD

# %%
def import_data():
    if not mt5.initialize():
    print("initialize() failed, error code =",mt5.last_error())
    quit()
    # set time zone to UTC
    
    timezone = pytz.timezone("Etc/UTC")
    # create 'datetime' objects in UTC time zone to avoid the implementation of a local time zone offset
    utc_from = datetime(2020, 2, 1, tzinfo=timezone)
    utc_to = datetime(2021, 2, 1, tzinfo=timezone)
    # get bars from USDJPY M5 within the interval of 2020.01.10 00:00 - 2020.01.11 13:00 in UTC time zone
    rates = mt5.copy_rates_range("BITCOIN", mt5.TIMEFRAME_D1, utc_from, utc_to)

    
    # create DataFrame out of the obtained data
    rates_frame = pd.DataFrame(rates)
    # convert time in seconds into the 'datetime' format
    #rates_frame['time']=pd.to_datetime(rates_frame['time'], unit='s')
    
    rates_frame
    rates_frame.to_csv('BTC20_21.csv')
    
    return rates_frame

# %%
#ENTRENAMIENTO
data_E=pd.read_csv('BTC19_20.csv')
data_E
# Out:
#      Unnamed: 0        time     open     high      low    close  tick_volume  \
# 0             0  1546387200  3776.40  3875.24  3746.32  3860.78      2241708
# 1             1  1546473600  3860.78  3891.23  3735.28  3770.96      7253573
# 2             2  1546560000  3770.96  3826.24  3706.38  3810.35     30337620
# 3             3  1546819200  4008.20  4046.24  3945.24  3981.47      3247554
# 4             4  1546905600  3981.47  4087.36  3926.25  3976.13      1649465
# ..          ...         ...      ...      ...      ...      ...          ...
# 254         254  1577145600  7294.75  7412.25  7139.25  7180.25       340064
# 255         255  1577318400  7162.75  7419.25  7150.25  7173.75       278882
# 256         256  1577404800  7172.75  7240.75  7026.75  7204.50       322672
# 257         257  1577664000  7373.00  7412.00  7181.50  7231.75       279110
# 258         258  1577750400  7202.75  7289.00  7097.50  7128.75       190402
#
#      spread  real_volume
# 0         0      5130062
# 1         0      6835392
# 2         0      6835366
# 3         0      6871753
# 4         0      6835387
# ..      ...          ...
# 254       0      3765000
# 255       0      3240000
# 256       0      4308954
# 257       0      4308833
# 258       0      3765253
#
# [259 rows x 9 columns]

# %%
#PRUEBA
data_P=pd.read_csv('BTC20_21.csv')

# %%
def tec1(data):
    df = data.copy()
    indicator_bb = BollingerBands(close=data.close, window=20, window_dev=2)
    df['bb_bbm'] = indicator_bb.bollinger_mavg()
    df['bb_bbh'] = indicator_bb.bollinger_hband()
    df['bb_bbl'] = indicator_bb.bollinger_lband()
    df['bb_high_signal'] = indicator_bb.bollinger_hband_indicator()
    df['bb_low_signal'] = indicator_bb.bollinger_lband_indicator()
    return df


def tec2(data):
    df = data.copy()
    indicator_stoc = StochasticOscillator(high=data['high'], low=data['low'], close=data['close'])
    df['stochastic'] = indicator_stoc.stoch()
    df['stochastic_buy_signal'] = indicator_stoc.stoch() < 20
    df['stochastic_sell_signal'] = indicator_stoc.stoch() > 80
    return df

# %%
data_ES = tec1(data_E)
data_ES.dropna()
# Out:
#      Unnamed: 0        time     open     high      low    close  tick_volume  \
# 19           19  1548720000  3392.98  3417.20  3317.93  3377.53      8052660
# 20           20  1548806400  3377.49  3435.44  3349.37  3408.75      4048838
# 21           21  1548892800  3408.75  3448.57  3372.38  3393.54       853227
# 22           22  1548979200  3393.54  3432.37  3350.26  3425.32      1652827
# 23           23  1549238400  3371.25  3411.60  3369.05  3393.46      2448519
# ..          ...         ...      ...      ...      ...      ...          ...
# 254         254  1577145600  7294.75  7412.25  7139.25  7180.25       340064
# 255         255  1577318400  7162.75  7419.25  7150.25  7173.75       278882
# 256         256  1577404800  7172.75  7240.75  7026.75  7204.50       322672
# 257         257  1577664000  7373.00  7412.00  7181.50  7231.75       279110
# 258         258  1577750400  7202.75  7289.00  7097.50  7128.75       190402
#
#      spread  real_volume     bb_bbm       bb_bbh       bb_bbl  bb_high_signal  \
# 19        0      6835329  3649.4195  4009.635486  3289.203514             0.0
# 20        0      6840090  3626.8180  3987.874719  3265.761281             0.0
# 21        0      6840127  3607.9470  3976.275437  3239.618563             0.0
# 22        0      6835363  3588.6955  3952.921372  3224.469628             0.0
# 23        0      6840262  3559.2950  3884.828327  3233.761673             0.0
# ..      ...          ...        ...          ...          ...             ...
# 254       0      3765000  7242.5675  7702.388425  6782.746575             0.0
# 255       0      3240000  7224.9950  7666.776683  6783.213317             0.0
# 256       0      4308954  7208.1835  7625.540470  6790.826530             0.0
# 257       0      4308833  7185.5555  7541.800531  6829.310469             0.0
# 258       0      3765253  7177.2500  7530.648465  6823.851535             0.0
#
#      bb_low_signal
# 19             0.0
# 20             0.0
# 21             0.0
# 22             0.0
# 23             0.0
# ..             ...
# 254            0.0
# 255            0.0
# 256            0.0
# 257            0.0
# 258            0.0
#
# [240 rows x 14 columns]

# %%
data_ES2 = tec2(data_E)
data_ES2.dropna()
# Out:
#      Unnamed: 0        time     open     high      low    close  tick_volume  \
# 13           13  1548028800  3515.45  3544.94  3482.49  3497.50      2451643
# 14           14  1548115200  3497.50  3587.53  3402.36  3549.88     10772862
# 15           15  1548201600  3549.88  3589.22  3498.51  3521.29      1651960
# 16           16  1548288000  3521.29  3572.07  3504.88  3547.24      4052829
# 17           17  1548374400  3547.24  3554.75  3490.64  3534.75      2454167
# ..          ...         ...      ...      ...      ...      ...          ...
# 254         254  1577145600  7294.75  7412.25  7139.25  7180.25       340064
# 255         255  1577318400  7162.75  7419.25  7150.25  7173.75       278882
# 256         256  1577404800  7172.75  7240.75  7026.75  7204.50       322672
# 257         257  1577664000  7373.00  7412.00  7181.50  7231.75       279110
# 258         258  1577750400  7202.75  7289.00  7097.50  7128.75       190402
#
#      spread  real_volume  stochastic  stochastic_buy_signal  \
# 13        0      6840151    4.344442                   True
# 14        0      6835359   21.535766                  False
# 15        0      6840203   17.362044                   True
# 16        0      6840137   21.150365                  False
# 17        0      6835422   19.327007                   True
# ..      ...          ...         ...                    ...
# 254       0      3765000   61.539946                  False
# 255       0      3240000   61.038209                  False
# 256       0      4308954   63.411810                  False
# 257       0      4308833   65.515245                  False
# 258       0      3765253   57.564647                  False
#
#      stochastic_sell_signal
# 13                    False
# 14                    False
# 15                    False
# 16                    False
# 17                    False
# ..                      ...
# 254                   False
# 255                   False
# 256                   False
# 257                   False
# 258                   False
#
# [246 rows x 12 columns]

# %%
def grafica_data_ABC(dataframe, graph, title_g): 
    fig=px.line(dataframe, x='TimeStamp', y= graph, color="Exchange",title=(title_g))
    return fig.show()

# %%
data_ES = tec1(data_E)
data_ES.dropna()

# %%
df_ret=pd.DataFrame(index = range(1,29), columns = ['Dias','Ret_anual', 'Std_anual','Radio_Sharpe'])
rf=0.045
for i in range(28):
    # Rendimientos si compraramos y vendieramos despues de i+1 dias
    ret_vec=data['close'].pct_change(i+1).dropna()
    ret_anual= ret_vec.mean()*(252/(i+1))
    std_anual=ret_vec.std()*np.sqrt((252/(i+1)))
    rs=(ret_anual-rf)/std_anual
    df_ret.iloc[i]=[i+1, ret_anual, std_anual, rs]
    
df_ret
# Out:
#    Dias Ret_anual Std_anual Radio_Sharpe
# 1     1  0.851355  0.718573     1.122161
# 2     2  0.864791  0.714145     1.147933
# 3     3  0.868878  0.717319     1.148552
# 4     4  0.853471  0.707933     1.142016
# 5     5  0.851763  0.712202     1.132772
# 6     6  0.853696  0.715258     1.130635
# 7     7  0.873537  0.727742     1.138504
# 8     8  0.886581  0.736302     1.142983
# 9     9  0.894459  0.738574     1.150134
# 10   10  0.896798  0.742232     1.147617
# 11   11  0.906497  0.750961     1.147192
# 12   12  0.916788  0.753044     1.157685
# 13   13  0.929887  0.761951     1.161344
# 14   14  0.942943  0.767174     1.170455
# 15   15  0.952318  0.769784     1.178664
# 16   16  0.961442  0.772665      1.18608
# 17   17  0.966951  0.767453     1.201312
# 18   18  0.973844  0.767072     1.210896
# 19   19  0.977385   0.75961     1.227453
# 20   20  0.985687  0.759213      1.23903
# 21   21  0.995862  0.762183     1.247551
# 22   22  1.006128  0.760278      1.26418
# 23   23  1.014477  0.757283     1.280204
# 24   24  1.024223  0.756813     1.293878
# 25   25  1.031022  0.756834     1.302824
# 26   26  1.038917  0.758049     1.311152
# 27   27  1.049215  0.762177     1.317561
# 28   28  1.057333  0.765977     1.321623
